# %%
import requests

from bs4 import BeautifulSoup

# %%
page_url = "https://search.yahoo.co.jp/image/search?p=%E7%8C%AB&oq=&ei=UTF-8&b=1"

r = requests.get(page_url)

soup = BeautifulSoup(r.text, features="html.parser")

# %%
soup.find_all("img", attrs={"alt": "「猫」の画像検索結果"})
# Out:
# [<img alt="「猫」の画像検索結果" rel="https://amd.c.yimg.jp/amd/20200207-00161928-roupeiro-000-34-view.jpg|https://msp.c.yimg.jp/yjimage?q=XKALa7UXyLEJkRtZ2e2YNd0ZiC_xqcYCS8i8l0J0uGXBMzbDXGxTAMP27iq5sU35Cl_4XvONOQop2OQCxGlnbkilQ2nzN0UWPxBvM4aYpvAjEHUObPJWUiV2kBVf_E95uDJ3Jv6YWXc9yXqZXUPp&amp;sig=13a8047c5&amp;x=300&amp;y=168|1920x1080|558.9kB|多数の応募から「世界最悪の猫」...|https://news.yahoo.co.jp/byline/ishiimasumi/20200207-00161928/|1|" src="https://msp.c.yimg.jp/yjimage?q=XKALa7UXyLEJkRtZ2e2YNd0ZiC_xqcYCS8i8l0J0uGXBMzbDXGxTAMP27iq5sU35Cl_4XvONOQop2OQCxGlnbkilQ2nzN0UWPxBvM4aYpvAjEHUObPJWUiV2kBVf_E95uDJ3Jv6YWXc9yXqZXUPp&amp;sig=13a8047c5&amp;x=300&amp;y=168"/>,
# ...

# %%
img_tags = soup.find_all("img", attrs={"alt": "「猫」の画像検索結果"})

# %%
img_urls = []

for img_tag in img_tags:
  url = img_tag.get("src")
  img_urls.append(url)
print(url)
# Out:
# https://msp.c.yimg.jp/yjimage?q=oD7ZT_YXyLEGqsFx457raQt_OOiC2QCyRGZzKODoIpgoT2301GhG31valrhArBqfGwnZRtgr9at8N6Bzf4VVEY9UXTmUtErnoB1uQIqwUZJuWIrvSAorssGfD27CmNynW8rPTnYGllLZdurBdAaT&sig=13a3ueo2k&x=170&y=297

# %%
def download_image(url, file_path):
  r = requests.get(url, stream=True)

  if r.status_code == 200:
    with open(file_path, "wb") as f:
      f.write(r.content)

# %%
from google.colab import drive
drive.mount('./gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at ./gdrive

# %%
import os

google_drive_save_dir = "/content/gdrive/My Drive/images/猫"

# %%
for n_page in range(1, 100, 20):
  print(n_page)
# Out:
# 1
# 21
# 41
# 61
# 81

# %%
def get_image_urls(page_url):
  img_urls = []

  r = requests.get(page_url)
  soup = BeautifulSoup(r.text, features="html.parser")

  img_tags = soup.find_all("img", attrs={"alt": "「猫」の画像検索結果"})

  for img_tag in img_tags:
    url = img_tag.get("src")
    img_urls.append(url)
  return img_urls

# %%
def loop_download_image(page_index, img_urls):
  for image_index, url in enumerate(img_urls):
    file_name = "{}_{}.jpg".format(page_index, image_index)
    image_path = os.path.join(google_drive_save_dir, file_name)
    print(image_path)

    download_image(url=url, file_path=image_path)

# %%
for index, n_page in enumerate(range(1, 100, 20)):
  print(n_page)
  page_url = "https://search.yahoo.co.jp/image/search?fr=top_ga1_sa&p=%E9%BD%8B%E8%97%A4%E9%A3%9B%E9%B3%A5&ei=UTF-8&b={}".format(n_page)

  img_urls = get_image_urls(page_url)

  loop_download_image(page_index=index+1, img_urls=img_urls)
# Out:
# 1
# /content/gdrive/My Drive/images/齋藤飛鳥/1_0.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_1.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_2.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_3.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_4.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_5.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_6.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_7.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_8.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_9.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_10.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_11.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_12.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_13.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_14.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_15.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_16.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_17.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_18.jpg
# /content/gdrive/My Drive/images/齋藤飛鳥/1_19.jpg
# 21
# ...
